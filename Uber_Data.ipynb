# %%
# %matplotlib notebook

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib
#from mpl_toolkits.basemap import Basemap

# %%
DATA_FILE = 'Uber_Clean.csv'
uber_data = pd.read_csv(DATA_FILE)
uber_data.head()
# Out:
#    Unnamed: 0        Date      Time  Month  Day  Year  locationID    borough  \
# 0           0  2015-05-17  09:47:00      5   17  2015         141  Manhattan
# 1           1  2015-05-17  09:47:00      5   17  2015          65   Brooklyn
# 2           2  2015-05-17  09:47:00      5   17  2015         100  Manhattan
# 3           3  2015-05-17  09:47:00      5   17  2015          80   Brooklyn
# 4           4  2015-05-17  09:47:00      5   17  2015          90  Manhattan
#
#                           zone service_zone ntacode  \
# 0              Lenox Hill West  Yellow Zone    MN31
# 1  Downtown Brooklyn/MetroTech    Boro Zone    BK38
# 2             Garment District  Yellow Zone    MN13
# 3            East Williamsburg    Boro Zone    BK90
# 4                     Flatiron  Yellow Zone    MN13
#
#                                 pickup_neighborhood
# 0                       Lenox Hill-Roosevelt Island
# 1  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
# ...

# %%
uber_data['Date'] = pd.to_datetime(uber_data['Date'], format="%Y-%m-%d")
uber_data['Time'] = pd.to_datetime(uber_data['Time'], format="%H:%M:%S")
uber_data['DayOfWeek'] = uber_data['Date'].dt.dayofweek
uber_data['HourOfDay'] = uber_data['Time'].dt.hour

# %%
uber_monthdays = uber_data.pivot_table(index=['DayOfWeekNum'],
                                  values='borough',
                                  aggfunc='count')
uber_monthdays.plot(kind='bar', figsize=(8,6))
plt.ylabel('Total Journeys')
plt.title('Journeys by Month Day');
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
uber_monthdays = uber_data.pivot_table(index=['Day'],
                                  values='borough',
                                  aggfunc='count')
uber_monthdays.plot(kind='bar', figsize=(8,6))
plt.ylabel('Total Journeys')
plt.title('Journeys by Month Day');
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
uber_hour = uber_data.pivot_table(index=['HourOfDay'],
                                  values='borough',
                                  aggfunc='count')
uber_hour.plot(kind='bar', figsize=(8,6))
plt.ylabel('Total Journeys')
plt.title('Journeys by Hour');
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
uber_monthdays = uber_data.pivot_table(index=['borough'],
                                  values='service_zone',
                                  aggfunc='count')
uber_monthdays.plot(kind='bar', figsize=(8,6))
plt.ylabel('Total Journeys')
plt.title('Journeys by Month Day');
# Out:
# <img src="data:image/png;base64,..." width="800">
